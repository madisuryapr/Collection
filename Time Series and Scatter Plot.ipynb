# %%
import numpy as np
import seaborn as sns
import pandas as pd
import matplotlib.pyplot as plt

# %%
sns.set_theme(style = "darkgrid")

# %%
Payments = pd.read_excel("Modeling_Dataset.xlsx")
Payments
# Out:
#           Date       IPI     NDEBIT    NCREDIT    NEMONEY  NCLEARING  \
# 0   2011-01-01  5.248991  17.809646   9.193239   5.189385   9.573282
# 1   2011-02-01  0.801809  18.089032  10.353259 -12.056982   6.256070
# 2   2011-03-01  4.429318  12.368791   4.424940 -12.349478   1.111657
# 3   2011-04-01  0.739353  14.644299   3.802341  13.889606   1.325409
# 4   2011-05-01  4.687810  17.313523  12.184497  24.099784  15.576149
# ..         ...       ...        ...        ...        ...        ...
# 118 2020-11-01 -8.108097  -2.016044 -31.693986  18.522224   5.784839
# 119 2020-12-01 -5.111593   1.601132 -36.458850  28.398884  -0.516697
# 120 2021-01-01 -7.562673  -1.850469 -37.248324  28.704586  -6.657721
# 121 2021-02-01 -7.186312  -4.970255 -34.423591  24.705407  -5.545665
# 122 2021-03-01  0.358582   8.953459 -12.467552  40.544856  12.216395
#
#          NRTGS     VDEBIT    VCREDIT    VEMONEY  VCLEARING      VRTGS
# ...

# %% [markdown]
# # Scatter Plot for Industrial Productivity vs Noncash Payments

# %%
# IPI vs Transactions Value (N) of Debit and Credit Cards
sns.pairplot(data = Payments, x_vars = ["NDEBIT", "NCREDIT"],
             y_vars = ["IPI"], height = 5, aspect = .8, kind = "reg");

# %%
# IPI vs Transactions Value (N) of Clearing and RTGS System
sns.pairplot(data = Payments, x_vars = ["NCLEARING", "NRTGS"],
             y_vars = ["IPI"], height = 5, aspect = .8, kind = "reg");

# %%
# IPI vs Transactions Volume (V) of Debit and Credit Cards
sns.pairplot(data = Payments, x_vars = ["VDEBIT", "VCREDIT"],
             y_vars = ["IPI"], height = 5, aspect = .8, kind = "reg");

# %%
# IPI vs Transactions Volume (V) of Clearing and RTGS System
sns.pairplot(data = Payments, x_vars = ["VCLEARING", "VRTGS"],
             y_vars = ["IPI"], height = 5, aspect = .8, kind = "reg");

# %% [markdown]
# # Time Series Plot for corresponding Variables

# %%
# Time series plot for Transactions Value of Debit Cards
Debits_Value = sns.relplot(data = Payments, x = "Date", y = "NDEBIT",
                          kind = "line", aspect = 1.25, color = "#415057");
Debits_Value.figure.autofmt_xdate()
plt.savefig("Debits_Value.png", dpi = 450)

# %%
# Time series plot for Transactions Value of Credit Cards
Debits_Value = sns.relplot(data = Payments, x = "Date", y = "NCREDIT",
                          kind = "line", aspect = 1.25, color = "#530B0E");
Debits_Value.figure.autofmt_xdate()
plt.savefig("Credits_Value.png", dpi = 450)

# %%
# Time series plot for Transactions Value of Electronic Money
Debits_Value = sns.relplot(data = Payments, x = "Date", y = "NEMONEY",
                          kind = "line", aspect = 1.25, color = "#274757");
Debits_Value.figure.autofmt_xdate()
plt.savefig("Emoney_Value.png", dpi = 450)

# %%
# Time series plot for Transactions Value of Sistem Kliring Nasional Bank Indonesia
Debits_Value = sns.relplot(data = Payments, x = "Date", y = "NCLEARING",
                          kind = "line", aspect = 1.25, color = "#3A7482");
Debits_Value.figure.autofmt_xdate()
plt.savefig("Clearing_Value.png", dpi = 450)

# %%
# Time series plot for Transactions Value of Bank Indonesia-Real Time Gross Settlement
Debits_Value = sns.relplot(data = Payments, x = "Date", y = "NRTGS",
                          kind = "line", aspect = 1.25, color = "#12998B");
Debits_Value.figure.autofmt_xdate()
plt.savefig("RTGS_Value.png", dpi = 450)

# %%
# Time series plot for Transactions Volume of Debit Cards
Debits_Value = sns.relplot(data = Payments, x = "Date", y = "VDEBIT",
                          kind = "line", aspect = 1.25, color = "#415057");
Debits_Value.figure.autofmt_xdate()
plt.savefig("Debits_Volume.png", dpi = 450)

# %%
# Time series plot for Transactions Volume of Credit Cards
Debits_Value = sns.relplot(data = Payments, x = "Date", y = "VCREDIT",
                          kind = "line", aspect = 1.25, color = "#530B0E");
Debits_Value.figure.autofmt_xdate()
plt.savefig("Credits_Volume.png", dpi = 450)

# %%
# Time series plot for Transactions Volume of Electronic Money
Debits_Value = sns.relplot(data = Payments, x = "Date", y = "VEMONEY",
                          kind = "line", aspect = 1.25, color = "#274757");
Debits_Value.figure.autofmt_xdate()
plt.savefig("Emoney_Volume.png", dpi = 450)

# %%
# Time series plot for Transactions Volume of Sistem Kliring Nasional Bank Indonesia
Debits_Value = sns.relplot(data = Payments, x = "Date", y = "VCLEARING",
                          kind = "line", aspect = 1.25, color = "#3A7482");
Debits_Value.figure.autofmt_xdate()
plt.savefig("Clearing_Volume.png", dpi = 450)

# %%
# Time series plot for Transactions Volume of Bank Indonesia-Real Time Gross Settlement
Debits_Value = sns.relplot(data = Payments, x = "Date", y = "VRTGS",
                          kind = "line", aspect = 1.25, color = "#12998B");
Debits_Value.figure.autofmt_xdate()
plt.savefig("RTGS_Volume.png", dpi = 450)
